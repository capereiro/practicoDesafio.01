# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import unidecode

# %%
df = pd.read_csv("properatti_minusculas.csv", encoding="UTF-8")

# %%
#Para ver todos las columnas y los textos completos

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %%
import seaborn as sns
sns.set(style="white")

# %%
sns.relplot(x="surface_covered_in_m2", 
            y="surface_total_in_m2", 
            hue="property_type", 
            sizes=(40, 400), 
            alpha=.5, 
            palette="colorblind",
            height=6, 
            data=df)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 operation property_type place_name  \
# 0  0           0             sell      PH            mataderos
# 1  1           1             sell      apartment     la plata
# 2  2           2             sell      apartment     mataderos
# 3  3           3             sell      PH            liniers
# 4  4           4             sell      apartment     centro
#
#                                          place_with_parent_names country_name  \
# 0  |argentina|capital federal|mataderos|                          Argentina
# 1  |argentina|bs.as. g.b.a. zona sur|la plata|                    Argentina
# 2  |argentina|capital federal|mataderos|                          Argentina
# 3  |argentina|capital federal|liniers|                            Argentina
# 4  |argentina|buenos aires costa atlantica|mar del plata|centro|  Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0  capital federal               3430787.0    -34.6618237,-58.5088387
# 1  bs.as. g.b.a. zona sur        3432039.0    -34.9038831,-57.9643295
# 2  capital federal               3430787.0    -34.6522615,-58.5229825
# 3  capital federal               3431333.0    -34.6477969,-58.5164244
# 4  buenos aires costa atlantica  3435548.0    -38.0026256,-57.5494468
#
#          lat        lon     price currency  price_aprox_local_currency  \
# 0 -34.661824 -58.508839  62000.0   USD      1093959.0
# 1 -34.903883 -57.964330  150000.0  USD      2646675.0
# 2 -34.652262 -58.522982  72000.0   USD      1270404.0
# 3 -34.647797 -58.516424  95000.0   USD      1676227.5
# 4 -38.002626 -57.549447  64000.0   USD      1129248.0
#
#    price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# 0  62000.0          55.0                 40.0
# 1  150000.0        NaN                  NaN
# 2  72000.0          55.0                 55.0
# 3  95000.0         NaN                  NaN
# 4  64000.0          35.0                 35.0
#
#    price_usd_per_m2  price_per_m2  floor  rooms  expenses  \
# 0  1127.272727       1550.000000  NaN    NaN    NaN
# 1 NaN               NaN           NaN    NaN    NaN
# 2  1309.090909       1309.090909  NaN    NaN    NaN
# 3 NaN               NaN           NaN    NaN    NaN
# 4  1828.571429       1828.571429  NaN    NaN    NaN
#
#                                                                                                                       properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mataderos_lavadero_patio_inmobiliaria-fedele
# 1  http://www.properati.com.ar/15bob_venta_departamentos_la-plata_balcon_lavadero_toilette_garage_estrenar_antonini-propiedades_dcp
# 2  http://www.properati.com.ar/15bod_venta_departamentos_mataderos_lavadero_placard_inmobiliaria-fedele
# 3  http://www.properati.com.ar/15boh_venta_ph_liniers_patio_g-goffredo
# 4  http://www.properati.com.ar/15bok_venta_departamentos_centro_cristina-pavone-negocios-inmobiliarios
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description  \
# 0  2 ambientes tipo casa planta baja por pasillo, refaccionado a nuevo, patio grande, con lavadero, living comedor con cocina integrada, artefacto de cocina, alacena, bano completo, y dormitorio. todo en excelente estado, para habitar.no es apto credito aviso publicado por pixel inmobiliario (servicio de paginas web para inmobiliarias).
# 1  venta de departamento en decimo piso al frente, a estrenar. living comedor con ventanales hacia el balcon con pisos de madera. cocina completa con doble mesada, muebles bajo mesada. lavadero separado. toilette.dormitorio con placard. segundo dormitorio a dividir. calefaccion por radiadorbano completo.balcon corrido. posibilidad de cochera semicubierta. u$d 20.000                     aviso publicado por pixel inmobiliario (servicio de paginas web para inmobiliarias).
# 2  2 ambientes 3er piso lateral living comedor amplio cocina separada con lavadero, bano completo y dormitorio con placard. bajas expensas, excelente ubicacion     aviso publicado por pixel inmobiliario (servicio de paginas web para inmobiliarias).
# 3  ph 3 ambientes con patio. hay 3 deptos en lote, 2 en pb y 1 en 1o piso.reciclado a nuevo. "muy buen estado"     aviso publicado por pixel inmobiliario (servicio de paginas web para inmobiliarias).
# 4  departamento con fantastica iluminacion natural,  al contrafrente, edificio de pocas unidades y muy bien conservado. en estado original.-posee: 1 dormitorios,  1 bano completo, living comedor y cocina separada.-en estado original.- aviso publicado por pixel inmobiliario (servicio de paginas web para inmobiliarias).
#
#                                                         title  \
# 0  2 amb tipo casa sin expensas en pb
# 1  venta depto 2 dorm. a estrenar 7 e/ 36 y 37
# 2  2 amb 3er piso con ascensor apto credito
# 3  ph 3 amb. cfte. reciclado
# 4  depto 2 amb al contrafrente zona centro/plaza mitre
#
#                                                                                                                                                                       image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIKufMJMwHtquzhk=/trim/198x0/smart/filters:strip_icc()/inmobiliariafedele.com/photos/CARHUE%202278-IMG_3400.JPG
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv45KAKirGL3JM8=/trim/198x0/smart/filters:strip_icc()/antoninipropiedades.com/photos/401-1-7%20y%2037%2010A%201.jpg
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_Ejwfu6QpW4cH0=/trim/198x0/smart/filters:strip_icc()/inmobiliariafedele.com/photos/GUAMINI%201171-IMG_3403.JPG
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SPyleyeQlIypI8w=/trim/198x0/smart/filters:strip_icc()/ggoffredo.com/photos/GG0040-1563480102.jpg
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f5l8TrxdY-0kvs=/trim/198x0/smart/filters:strip_icc()/cristinapavone.com/photos/66-thumbnail_20170126_120753_1485788428321_resized.jpg

# %%
df.shape
# Out:
# (121220, 27)

# %%
df['state_name'].value_counts()
# Out:
# capital federal                 32316
# bs.as. g.b.a. zona norte        25560
# bs.as. g.b.a. zona sur          13952
# cordoba                         12069
# santa fe                        10172
# buenos aires costa atlantica    10006
# bs.as. g.b.a. zona oeste        9322
# buenos aires interior           2291
# rio negro                       808
# neuquen                         733
# mendoza                         681
# tucuman                         674
# corrientes                      583
# misiones                        464
# entre rios                      369
# salta                           278
# chubut                          259
# san luis                        252
# la pampa                        157
# formosa                         65
# chaco                           57
# san juan                        40
# tierra del fuego                31
# catamarca                       27
# jujuy                           26
# santa cruz                      20
# la rioja                        4
# santiago del estero             4
# Name: state_name, dtype: int64

# %%
# Queremos ver cuantos valores hay en cada Barrio
df['place_name'].value_counts()
# Out:
# cordoba                      9254
# rosario                      8504
# mar del plata                6534
# tigre                        3324
# nordelta                     3315
#                              ...
# barrio los tilos             1
# la punilla                   1
# barrio cerrado san andres    1
# pueblo liebig                1
# barrio cerrado la cascada    1
# Name: place_name, Length: 1058, dtype: int64

# %%
df[df.state_name =='capital federal']['place_name'].value_counts()
# Out:
# belgrano           2992
# palermo            2885
# caballito          2273
# villa urquiza      1629
# recoleta           1547
#                    ...
# velez sarsfield    39
# villa real         37
# villa soldati      15
# villa riachuelo    6
# catalinas          4
# Name: place_name, Length: 62, dtype: int64

# %%
# Queremos ver cuantos valores hay en cada barrio de Capital Federal
df[df.state_name =='capital federal']['place_name'].value_counts()
# Out:
# belgrano           2992
# palermo            2885
# caballito          2273
# villa urquiza      1629
# recoleta           1547
#                    ...
# velez sarsfield    39
# villa real         37
# villa soldati      15
# villa riachuelo    6
# catalinas          4
# Name: place_name, Length: 62, dtype: int64

# %%
display(df[df.state_name =='capital federal']['place_name'].value_counts())
# Out:
# belgrano           2992
# palermo            2885
# caballito          2273
# villa urquiza      1629
# recoleta           1547
#                    ...
# velez sarsfield    39
# villa real         37
# villa soldati      15
# villa riachuelo    6
# catalinas          4
# Name: place_name, Length: 62, dtype: int64

# %%
#df1 = df.sample(100)

# %%
dfa = df[['place_name','price_aprox_usd']].dropna() # Sacamos los nulos

# %%
# Queremos sacar los place_names con una frecuencia menos a x casos
dfa = dfa.groupby('place_name').filter(lambda x: len(x) > 100)
dfa.shape
# Out:
# (89817, 2)

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x) # Para sacar la notacion cientifica

# %%
xx = dfa.groupby('place_name').describe().astype(int)

# %% [markdown]
# Precio promedio

# %%
xx[('price_aprox_usd', 'mean')].sort_values(ascending=False).head(10).plot.bar()

# %%
dfb = df[['property_type','price_aprox_usd']].dropna() # Sacamos los nulos

# %%
# Queremos sacar los place_names con una frecuencia menos a x casos
dfb = dfb.groupby('property_type').filter(lambda x: len(x) > 100)
dfa.shape
# Out:
# (89817, 2)

# %%
xxB = dfb.groupby('property_type').describe().astype(int)

# %%
xxB
# Out:
#               price_aprox_usd                                                \
#                         count    mean     std   min     25%     50%     75%
# property_type
# PH             5220            147689  148894  5047  85000   120000  165000
# apartment      59616           187406  316218  4666  80000   119000  190000
# house          32715           329696  458208  0     140000  240000  384450
# store          3259            440257  761393  4952  95000   210000  450000
#
#
#                     max
# property_type
# PH             2800000
# apartment      46545445
# house          25000000
# store          13000000

# %%
# titanic = sns.load_dataset("titanic")
# sns.countplot(y="deck", hue="class", data=titanic, palette="Greens_d",
#               order=titanic.deck.value_counts().iloc[:3].index)

# %% [markdown]
# # grafico de cantidad por tipo y por barrio  ## me estafaltando ordenarlo

# %%
sns.catplot(y="place_name", hue="property_type", kind="count",
            palette="pastel", edgecolor=".6",
            data=df[df.state_name =='capital federal'], order=df.place_name.value_counts().iloc[:20].index);

# %%
xxB["property_type"].value_countsa().plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f013780325d6> in <module>
# ----> 1 xxB["property_type"].value_counts().plot(kind='hist')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2977         if is_single_key:
#    2978             if self.columns.nlevels > 1:
# -> 2979                 return self._getitem_multilevel(key)
#    2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3026
#    3027     def _getitem_multilevel(self, key):
# -> 3028         loc = self.columns.get_loc(key)
#    3029         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    3030             new_columns = self.columns[loc]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2672
#    2673         if not isinstance(key, tuple):
# -> 2674             loc = self._get_level_indexer(key, level=0)
#    2675             return _maybe_to_slice(loc)
#    2676
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2937         else:
#    2938
# -> 2939             code = level_index.get_loc(key)
#    2940
#    2941             if level > 0 or self.lexsort_depth == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'

# %%
xxB[('property_type')].value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-47f1baf7e3c6> in <module>
# ----> 1 xxB[('property_type')].value_counts().plot(kind='bar')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2977         if is_single_key:
#    2978             if self.columns.nlevels > 1:
# -> 2979                 return self._getitem_multilevel(key)
#    2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3026
#    3027     def _getitem_multilevel(self, key):
# -> 3028         loc = self.columns.get_loc(key)
#    3029         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    3030             new_columns = self.columns[loc]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2672
#    2673         if not isinstance(key, tuple):
# -> 2674             loc = self._get_level_indexer(key, level=0)
#    2675             return _maybe_to_slice(loc)
#    2676
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2937         else:
#    2938
# -> 2939             code = level_index.get_loc(key)
#    2940
#    2941             if level > 0 or self.lexsort_depth == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'

# %%
xxB[('property_type')].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e9e4ea8ccd1b> in <module>
# ----> 1 xxB[('property_type')].plot.bar()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2977         if is_single_key:
#    2978             if self.columns.nlevels > 1:
# -> 2979                 return self._getitem_multilevel(key)
#    2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3026
#    3027     def _getitem_multilevel(self, key):
# -> 3028         loc = self.columns.get_loc(key)
#    3029         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    3030             new_columns = self.columns[loc]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2672
#    2673         if not isinstance(key, tuple):
# -> 2674             loc = self._get_level_indexer(key, level=0)
#    2675             return _maybe_to_slice(loc)
#    2676
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2937         else:
#    2938
# -> 2939             code = level_index.get_loc(key)
#    2940
#    2941             if level > 0 or self.lexsort_depth == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'property_type'

# %%
xx[('price_aprox_usd', 'mean')].sort_values(ascending=False).head(30).plot.bar()

# %%
df

# %%
df = df[['property_type']].dropna() # Sacamos los nulos

# %%
# Queremos sacar los place_names con una frecuencia menos a x casos
df2 = df.groupby('property_type').filter(lambda x: len(x) > 100)

# %%
df2

# %%
x2 = df.groupby("property_type").describe().astype(int)

# %%
df1

# %%
sns.relplot(x="surface_covered_in_m2", 
            y="surface_total_in_m2", 
            hue="property_type", 
            sizes=(40, 400), 
            alpha=.5, 
            palette="colorblind",
            height=6, 
            data=df)

# %%
sns.relplot(x="surface_covered_in_m2", 
            y="surface_total_in_m2", 
            hue="property_type", 
            sizes=(40, 400), 
            alpha=.5, 
            palette="colorblind",
            height=6, 
            data=df)
